# %%
import pandas as pd
import statistics as st

# %%
cust_db = pd.read_csv('C:/Users/gelarani/OneDrive - PT Telekomunikasi Selular/Documents/TELKOMSEL/CMBM Division - HQ/2019/Others/DSA/05 Pre-Test/churn.csv',encoding='latin1')
cust_db.head(10)
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
# 5      1             118        510          3355                   1
# 6     19             121        510          1516                   0
# 7     24             147        415           116                   1
# 8     18             117        408           425                   0
# 9     49             141        415           163                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# ...

# %%
cust_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
# state                            5000 non-null int64
# account_length                   5000 non-null int64
# area_code                        5000 non-null int64
# phone_number                     5000 non-null int64
# international_plan               5000 non-null int64
# voice_mail_plan                  5000 non-null int64
# number_vmail_messages            5000 non-null int64
# total_day_minutes                5000 non-null float64
# total_day_calls                  5000 non-null int64
# total_day_charge                 5000 non-null float64
# total_eve_minutes                5000 non-null float64
# total_eve_calls                  5000 non-null int64
# total_eve_charge                 5000 non-null float64
# total_night_minutes              5000 non-null float64
# total_night_calls                5000 non-null int64
# ...

# %%
numeric_variable = ['number_vmail_messages','total_day_minutes','total_day_calls','total_day_charge','total_eve_minutes','total_eve_calls',
                    'total_eve_charge','total_night_minutes','total_night_calls','total_night_charge','total_intl_minutes','total_intl_calls',
                   'total_intl_calls', 'number_customer_service_calls']

# %%
cust_db.describe()
# Out:
#             state  account_length    area_code  phone_number  \
# count  5000.00000      5000.00000  5000.000000   5000.000000
# mean     25.99840       100.25860   436.911400   2499.500000
# std      14.80348        39.69456    42.209182   1443.520003
# min       0.00000         1.00000   408.000000      0.000000
# 25%      13.00000        73.00000   408.000000   1249.750000
# 50%      26.00000       100.00000   415.000000   2499.500000
# 75%      39.00000       127.00000   415.000000   3749.250000
# max      50.00000       243.00000   510.000000   4999.000000
#
#        international_plan  voice_mail_plan  number_vmail_messages  \
# count         5000.000000      5000.000000            5000.000000
# mean             0.094600         0.264600               7.755200
# std              0.292691         0.441164              13.546393
# min              0.000000         0.000000               0.000000
# 25%              0.000000         0.000000               0.000000
# ...

# %% [markdown]
# ## 1. Korelasi Total Minutes ke Variable

# %%
abs(cust_db[numeric_variable].corr()['total_day_minutes']).sort_values(ascending=False).head(14)
# Out:
# total_day_minutes                1.000000
# total_day_charge                 1.000000
# total_intl_minutes               0.019486
# total_night_minutes              0.011799
# total_night_charge               0.011783
# total_eve_charge                 0.010760
# total_eve_minutes                0.010750
# total_eve_calls                  0.008128
# number_vmail_messages            0.005381
# total_night_calls                0.004236
# number_customer_service_calls    0.002733
# total_day_calls                  0.001935
# total_intl_calls                 0.001303
# total_intl_calls                 0.001303
# Name: total_day_minutes, dtype: float64

# %% [markdown]
# ## 2. Profiling Customer Churn dan Stay

# %%
## grouping class ke churn dan stay cutomer type
class_group = ["Churn" if x>= 1 else "Stay" for x in cust_db['class']]
cust_db['class_group'] = class_group

# %%
churn_cb = cust_db[cust_db['class_group']=="Churn"]
stay_cb = cust_db[cust_db['class_group']=="Stay"]

# %%
## Average dari customer stay untuk total usage
column_select = ['total_day_charge','total_day_minutes', 'total_day_calls']

stay_cb[column_select].mean().round(2)
# Out:
# total_day_charge      29.88
# total_day_minutes    175.75
# total_day_calls       99.90
# dtype: float64

# %%
## Average dari customer churn untuk total usage
churn_cb[column_select].mean().round(2)
# Out:
# total_day_charge      35.34
# total_day_minutes    207.87
# total_day_calls      100.82
# dtype: float64

# %%
## Top kontributor state dari customer stay

stay_cb['state'].mode().round(2)
# Out:
# 0    49
# dtype: int64

# %%
## Top kontributor state dari customer churn
churn_cb['state'].mode().round(2)
# Out:
# 0    31
# dtype: int64

# %%
## korelasi total day charge untuk churn customer
abs(churn_cb[numeric_variable].corr()['total_day_charge']).sort_values(ascending=False).head(14)
# Out:
# total_day_charge                 1.000000
# total_day_minutes                1.000000
# number_customer_service_calls    0.394090
# total_eve_minutes                0.223746
# total_eve_charge                 0.223733
# number_vmail_messages            0.199075
# total_night_minutes              0.124659
# total_night_charge               0.124612
# total_intl_calls                 0.096580
# total_intl_calls                 0.096580
# total_day_calls                  0.031430
# total_night_calls                0.026028
# total_intl_minutes               0.024649
# total_eve_calls                  0.005621
# Name: total_day_charge, dtype: float64

# %%
## korelasi total day charge untuk stay customer
abs(stay_cb[numeric_variable].corr()['total_day_charge']).sort_values(ascending=False).head(14)
# Out:
# total_day_charge                 1.000000
# total_day_minutes                1.000000
# total_eve_charge                 0.089636
# total_eve_minutes                0.089629
# number_customer_service_calls    0.080920
# number_vmail_messages            0.068843
# total_intl_minutes               0.035753
# total_night_charge               0.024901
# total_night_minutes              0.024892
# total_eve_calls                  0.013172
# total_intl_calls                 0.012210
# total_intl_calls                 0.012210
# total_day_calls                  0.009339
# total_night_calls                0.001273
# Name: total_day_charge, dtype: float64

# %%
cust_db.drop(['class'],axis=1).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023F7A860550>,
# ...
#       dtype=object)
